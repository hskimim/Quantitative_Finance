# %% [markdown]
# 상장법인목록

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from io import BytesIO

# %%
def stock_master():
    url='http://kind.krx.co.kr/corpgeneral/corpList.do'
    data={
    'method': 'download',
    'orderMode': '3',   #정렬컬럼
    'orderStat': 'D',   #정렬 내림차순
    'searchType': '13' , #검색유형 : 상장법인
    'fiscalYearEnd': 'all', #결산월 : 전체
    'location': 'all', #지역 : 전체
    }
    
    r=requests.post(url,data=data)
    f=BytesIO(r.content)
    dfs=pd.read_html(f,header=0,parse_dates=['상장일'])
    df=dfs[0]
    
    df['종목코드']=df['종목코드'].astype(np.str)
    df['종목코드']=df['종목코드'].str.zfill(6)
    return df

# %%
df_master = stock_master()
df_master.head()
# Out:
#          회사명    종목코드                                 업종  \
# 0  HDC현대산업개발  294870                             건물 건설업
# 1  하나금융11호스팩  284620                         금융 지원 서비스업
# 2        파워넷  037030  전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 3       현대사료  016790                  동물용 사료 및 조제식품 제조업
# 4      세종메디칼  258830                         의료용 기기 제조업
#
#                      주요제품        상장일  결산월      대표자명  \
# 0  외주주택, 자체공사, 일반건축, 토목 등 2018-06-12  12월   김대철,권순호
# 1                  기업인수합병 2018-06-08  12월       남강욱
# 2                  전력변환장치 2018-06-07  12월  김상우, 양승환
# 3             양계, 양돈 배합사료 2018-06-01  12월       문철명
# 4            복강경수술용 투관침 등 2018-05-29  12월       정현국
#
#                            홈페이지     지역
# 0        http://www.hdc-dvp.com  서울특별시
# 1                           NaN  서울특별시
# 2     http://www.gopowernet.com  서울특별시
# 3       http://www.hdfeed.co.kr   충청남도
# 4  http://www.sejongmedical.com    경기도
