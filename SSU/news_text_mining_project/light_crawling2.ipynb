# %%
from first_project import *

# %%
ls = operate_light_crawling(2,make_df=False)
ls
# Out:
# #### vers :2 , make_df : False
# ...

# %%
df = operate_light_crawling(3,PageNum=3,make_df=True)
df
# Out:
# #### vers :3 , make_df : True
# 1th data is not crawled. but we're gonna ignore it.
# ### This report is from year : 2018-09-05 15:32
#                                                   0   \
# 0  (상하이=연합뉴스) 차대운 특파원 = 중국의 8월 소비자물가지수(CPI)가 작년 같...
#
#                                                   1   \
# 0  [한겨레] “일본과의 무역 협상 시작했다.\n\n합의 안 되면 일본에 큰 문제”\n...
#
#                                                   2   \
# 0  글로벌 금융위기 10년\n\n'10년 주기설'에 세계시장 긴장\n\n[ 김현석 기자...
#
#                                                   3   \
# 0  터키·아르헨티나 금융위기, 신흥국으로 확산…증시도 '휘청'\n\n경상수지 적자, 대...
#
#                                                   4   \
# 0  대미 무역흑자 310억5천만달러 기록\n\n"달러 강세·美 경기호조가 관세 효과 상...
#
#                                                   5   \
# 0  8월말 기준 3조1천97억달러…중국 당국 "달러 강세 영향"\n\n나란히 놓인 달러...
#
#                                                   6   \
# 0  도널드 트럼프 미국 대통령이 6일 (현지시간) 몬태나 주 빌링스의 ‘미국을 다시 위...
#
#                                                   7   \
# ...

# %%
df.shape
# Out:
# (1, 20)

# %%
ls1 = light_crawling2(PageNum=1,day_ago=4)
ls2 = light_crawling2(PageNum=2,day_ago=4)
ls = ls1 + ls2
len(ls)
# Out:
# 145

# %%
df = pd.DataFrame(data=ls,columns=['report_bundles'])

# %%
df.to_csv('light_crawling2.csv')
(pd.read_csv('light_crawling2.csv')).shape
# Out:
# (145, 2)
