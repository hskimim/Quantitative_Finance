# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from statsmodels.api import *

# %%
code_df = pd.read_csv('industrial_code.csv')

# %%
code_df.rename(columns={'종목코드':'code'},inplace=True)

# %%
code_df = code_df[:401]

# %%
len(list(code_df['code']))
# Out:
# 401

# %%
num_of_stock = 100
T = 1000

# %%
np.random.rand()
# Out:
# 0.9611234112396715

# %%
df = pd.DataFrame(columns=[i for i in range(1,T+1)])

# %%
for i in df.columns:
    df[i] = [0 for i in range(401)]

# %%
df.index = list(code_df['code'])

# %%
for i in range(len(df)):
    df.iloc[i] = [1000*(np.random.randint(5,10))*(1+np.random.rand()) for _ in range(1000)]

# %%
df.index = [str(i) for i in df.index]

# %%
df.tail()
# Out:
#                1            2             3             4             5     \
# 12610   8864.725278  6966.516818   6550.344442   5123.745903  13440.386970
# 17810  10634.104047  9192.940386  13706.424938  11091.313199  10598.204994
# 11200   8848.193069  8284.962562  14555.350189  11256.509946   6397.397952
# 17390  12603.340942  9944.761126   5763.928751  14430.835183   7099.621209
# 25820   9587.436325  8754.588061   5476.549855  12888.217387  12628.580652
#
#                6             7             8             9             10    \
# 12610   9220.421889   9076.703245   7756.056370  14473.736353  10830.998481
# 17810  13172.594359   8910.106901   6797.047858   9698.234541   9529.482642
# 11200   7692.297102  13094.341322   8333.520301   5977.984388  11353.679297
# 17390  10730.058551   7368.052245  11574.516506  12582.602719   7210.380418
# 25820  11351.998759   5742.788986  11081.021764  13953.268932   7346.894746
#
# ...

# %%
df.rename(index={'11300':'market'},inplace=True)

# %%
df.tail()
# Out:
#                1            2             3             4             5     \
# 12610   8864.725278  6966.516818   6550.344442   5123.745903  13440.386970
# 17810  10634.104047  9192.940386  13706.424938  11091.313199  10598.204994
# 11200   8848.193069  8284.962562  14555.350189  11256.509946   6397.397952
# 17390  12603.340942  9944.761126   5763.928751  14430.835183   7099.621209
# 25820   9587.436325  8754.588061   5476.549855  12888.217387  12628.580652
#
#                6             7             8             9             10    \
# 12610   9220.421889   9076.703245   7756.056370  14473.736353  10830.998481
# 17810  13172.594359   8910.106901   6797.047858   9698.234541   9529.482642
# 11200   7692.297102  13094.341322   8333.520301   5977.984388  11353.679297
# 17390  10730.058551   7368.052245  11574.516506  12582.602719   7210.380418
# 25820  11351.998759   5742.788986  11081.021764  13953.268932   7346.894746
#
# ...

# %%
individual_stock_df = df[df.index != 'market']

# %%
individual_stock_df.shape
# Out:
# (400, 1000)

# %%
for i,value in enumerate(individual_stock_df.index):
    globals()['model'+str(i)] = OLS(individual_stock_df.loc[value].T,df.loc['market'][:, np.newaxis])
    globals()['result'+str(i)] = globals()['model'+str(i)].fit()
    globals()['params'+str(i)] = globals()['result'+str(i)].params.values[0]
#     display(globals()['result'+str(i)].summary())

# %%
beta_bundels = [globals()['params'+str(i)] for i in range(len(individual_stock_df.index))]

# %%
sorted_beta_bundles = sorted(beta_bundels)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
len(sorted_beta_bundles)
# Out:
# 400

# %%
sorted_beta_bundles
# Out:
# [0.90320658217919303,
#  0.9078384098523733,
#  0.91140078089354437,
#  0.91145070797869365,
#  0.91192596106666235,
#  0.91289441714834407,
#  0.91294924629116225,
#  0.91339328756128213,
#  0.91341989249594313,
#  0.91345745714387272,
#  0.91450165746066792,
#  0.91476086078522645,
#  0.91519809544740305,
#  0.91607298788004288,
#  0.91629356571159182,
#  0.91636310845321711,
#  0.91650678952358766,
#  0.91651710034387368,
#  0.91696680144379972,
#  0.91704958176601448,
#  0.91739264886814276,
#  0.91759790483900461,
#  0.91826520434009418,
#  0.91829242475763184,
#  0.91860592723055756,
#  0.91897579432598064,
#  0.91901541858310998,
#  0.91925568621002651,
#  0.91925975058089104,
#  0.91931515232400818,
#  0.91941703944073461,
#  0.91958235470851135,
#  0.91974309335603177,
#  0.91979907046817322,
#  0.91990121187802121,
#  0.91997842808274288,
#  0.92033160260558178,
#  0.92037030592795321,
#  0.9203956888279512,
#  0.92044627024954451,
#  0.92045113635745401,
# ...

# %%
portfolio_beta_20_1

# %%
for i in range(20):
    ls = []
    for _ in range(20):
        ls.append(sorted_beta_bundles.pop())
    globals()['portfolio_beta_20_'+str(i)] = ls.copy()

# %%
beta_ls = []
for i in range(20):
    beta_ls.append(sum(globals()['portfolio_beta_20_'+str(i)])/len(globals()['portfolio_beta_20_'+str(i)]))

# %%
beta_ls
# Out:
# [0.94983315105083288,
#  0.94469980869158809,
#  0.94171227016752324,
#  0.93936887180538697,
#  0.93802209517488977,
#  0.93660678966001498,
#  0.93514257909553034,
#  0.93368641032216426,
#  0.93253340375179605,
#  0.93171993328514824,
#  0.93075301632550289,
#  0.929578451381462,
#  0.92864783746654567,
#  0.92759352331341771,
#  0.92626672056059733,
#  0.92443517581269652,
#  0.92269102289780258,
#  0.92118123089666071,
#  0.91929704888023489,
#  0.9136083645713251]
