# %%
import pandas as pd
from IPython.display import display

# %%
df1 = pd.read_csv('KOSPI_BETA_MONTHLY.csv',encoding = "ISO-8859-1")
df2 = pd.read_csv('KOSPI_SILH_SUIK_RT_WITH_DIVIDEND_MONTHLY.csv',encoding = "ISO-8859-1")
df1.shape , df2.shape
# Out:
# ((358, 769), (358, 759))

# %%
df1.index = df1.iloc[:,0]
df1 = df1.iloc[12:,1:]
df1.columns =  ['stock'+str(idx) for idx,val in enumerate(df1.columns)]
df1.fillna(0,inplace=True)
display(df1.tail())

df2.index = df2.iloc[:,0]
df2 = df2.iloc[12:,1:]
df2.columns =  ['stock'+str(idx) for idx,val in enumerate(df2.columns)]
df2.fillna(0,inplace=True)
display(df2.tail())

print(df1.shape , df2.shape)
# Out:
#              stock0    stock1    stock2    stock3     stock4    stock5  \
# stock0
# 0.072290   0.946680  1.019230  0.862940  0.750590  -0.355130  0.183090
# 0.072290   0.946680  1.019230  0.862940  0.750590  -0.355130  0.183090
# 0.087440   0.693620  1.268160  0.757720  0.960260   0.111340  0.304170
# -0.202920  0.618380  1.365030  0.606540  0.937990  -0.018200  0.300500
# -0.202920  0.618380  1.365030  0.606540  0.937990  -0.018200  0.300500
#
#              stock6    stock7    stock8    stock9    ...    stock757 stock758  \
# stock0                                               ...
# 0.072290   0.979490  0.576260  0.056730  2.007160    ...           0        0
# 0.072290   0.979490  0.576260  0.056730  2.007160    ...           0        0
# 0.087440   1.082160  0.327530  0.314230  1.826130    ...           0        0
# -0.202920  1.045540  0.452560  0.036320  2.050600    ...           0        0
# -0.202920  1.045540  0.452560  0.036320  2.050600    ...           0        0
#
# ...
