# %%
from extract_reference import *

# %%
file = extract_text_from_pdf('09800628.pdf')

# %%
references = make_references('참 고 문 헌','107-124.',file)

# %%
new_references = make_new_references(references)

# %%
df = make_idx(new_references,references)

# %%
df
# Out:
#                                                person  \
# 0                                               강석규,
# 1                               .김지영, 강나은, 허지석, 채수빈,
# 2                                         .염명훈, 백재승,
# 3                                    .염명훈, 백재승, 류두진,
# 4                                             . 이상원,
# 5                                              .홍정효,
# 6                                             . 홍정효,
# 7                                              .홍정효,
# 8                    .Baek, J., J. Kim, and M. Yeom,
# 9             .   Barclay, M. J. and T. Hendershott,
# 10                    .Bauer, D. G. and B. M. Lucey,
# 11                .Bauer, D. G. and T. K. McDermott,
# 12          .Beckmann, J., T. Berger, and R. Czudaj,
# 13                                        .Chan, K.,
# 14                       .Chen, Y. L. and Y. F. Gau,
# 15  .
# KRX금시장과 국제금융시장의 상호연관성에 관한 연구367Choudhary, K....
# 16         .Ciner, C., C. Gurdgiev, and B. M. Lucey,
# ...

# %%
df = total_sequence_func('09800628.pdf','참 고 문 헌','107-124.')

# %%
df
# Out:
#                                                person  \
# 0                                               강석규,
# 1                               .김지영, 강나은, 허지석, 채수빈,
# 2                                         .염명훈, 백재승,
# 3                                    .염명훈, 백재승, 류두진,
# 4                                             . 이상원,
# 5                                              .홍정효,
# 6                                             . 홍정효,
# 7                                              .홍정효,
# 8                    .Baek, J., J. Kim, and M. Yeom,
# 9             .   Barclay, M. J. and T. Hendershott,
# 10                    .Bauer, D. G. and B. M. Lucey,
# 11                .Bauer, D. G. and T. K. McDermott,
# 12          .Beckmann, J., T. Berger, and R. Czudaj,
# 13                                        .Chan, K.,
# 14                       .Chen, Y. L. and Y. F. Gau,
# 15  .
# KRX금시장과 국제금융시장의 상호연관성에 관한 연구367Choudhary, K....
# 16         .Ciner, C., C. Gurdgiev, and B. M. Lucey,
# ...
