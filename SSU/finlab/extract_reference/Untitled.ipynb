# %%
import extract_reference as ref
import re
import os

# %%
file_list = os.listdir("paper_list")

# %%
result_1 = [ file_name for file_name in file_list if file_name.endswith(".pdf") ]
result_1 = ['paper_list/'+i for i in result_1]
len(result_1)
# Out:
# 496

# %%
idx_ls = []
df = []
for idx,i in enumerate(result_1) : 
    try : 
        df.append(ref.total_sequence_func(i))
        print('ok')
    except : 
        print(i)
        idx_ls.append(idx)
print(idx_ls)
# Out:
# paper_list/20180725162729_MM.pdf
# paper_list/0daa68a8_2-2.사전 정보유출이 주가에 미치는 영향 분석.pdf
# paper_list/20161226134111_RX.pdf
# paper_list/d4715a89_1-2.지배구조와인력구조가수출기업성과에미치는영향.pdf
# paper_list/a3f787b1_[권택호].pdf
# paper_list/20180810121313_FZ.pdf
# paper_list/ee5c195f_전상경,이용석.pdf
# paper_list/20180725163619_SC.pdf
# ok
# paper_list/20180725163237_EF.pdf
# paper_list/f62b73a0_[강형철,박경서,엄경식].pdf
# paper_list/7ac210d2_[Na Dai,Hoje Jo,John Schatzberg]-한미.pdf
# paper_list/111f60a1_2012_FullPaper38_KAFA_변종수.pdf
# paper_list/661e0a43_2012_FullPaper62_유원석.pdf
# paper_list/2e69c463_7-1.Correlation spillover effect over crises Evidence from Chinese sectors.pdf
# paper_list/9497d1fd_박경서, 변희섭.pdf
# ok
# ok
# paper_list/6bddf9cc_23-2.Can Local Long-term Institutional Ownership Alleviate....pdf
# paper_list/9ccfcea7_kospi200A+6_kwon_20121109.pdf
# paper_list/1f76ab48_[정영식].pdf
# paper_list/7facb0c2_손욱,엄윤성,한재훈.pdf
# paper_list/20180725162449_RX.pdf
# paper_list/14a4b1d5_[김윤영,이진수].pdf
# ...

# %%
len(idx_ls)
# Out:
# 385

# %%
len(idx_ls) / len(result_1)
# Out:
# 0.7762096774193549

# %%
sucess_list = [i for i in range(len(result_1)) if i not in idx_ls]

# %%
sucess_list
# Out:
# [8,
#  16,
#  17,
#  25,
#  36,
#  40,
#  48,
#  50,
#  60,
#  87,
#  88,
#  98,
#  100,
#  104,
#  112,
#  118,
#  127,
#  129,
#  132,
#  136,
#  138,
#  146,
#  153,
#  157,
#  158,
#  162,
#  164,
#  165,
#  179,
#  181,
#  186,
#  187,
#  192,
#  199,
#  201,
#  212,
#  222,
#  226,
#  229,
#  233,
#  235,
#  238,
#  241,
#  245,
#  254,
#  255,
#  259,
#  262,
#  266,
#  269,
#  274,
#  277,
#  282,
#  287,
#  293,
#  298,
#  299,
#  300,
#  301,
#  310,
#  317,
#  325,
#  335,
#  338,
#  339,
#  341,
#  342,
#  344,
#  345,
#  352,
#  353,
#  355,
#  356,
#  359,
#  361,
#  362,
#  364,
#  377,
#  378,
#  382,
#  385,
#  387,
#  392,
#  395,
#  398,
#  403,
#  404,
#  406,
#  425,
#  427,
#  434,
#  437,
#  439,
#  441,
#  443,
#  447,
#  452,
#  457,
#  460,
#  461,
#  465,
#  467,
#  470,
#  475,
#  476,
#  477,
#  480,
#  483,
#  488,
#  489,
#  494]
